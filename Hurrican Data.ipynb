# %%
import pandas as pd
import folium

# %%
data = pd.read_csv("./data.csv")

# %%
data.head()
# Out:
#    Name        date_time  Year  Month  Day  Hours_in_UTC  Latitude  Longitude  \
# 0  ABLE  1950/8/12 00:00  1950      8   12             0      17.1      -55.5
# 1  ABLE  1950/8/12 06:00  1950      8   12             6      17.7      -56.3
# 2  ABLE  1950/8/12 12:00  1950      8   12            12      18.2      -57.4
# 3  ABLE  1950/8/12 18:00  1950      8   12            18      19.0      -58.6
# 4  ABLE  1950/8/13 00:00  1950      8   13             0      20.0      -60.0
#
#    Maximum_sustained_wind_in_knots
# 0                               35
# 1                               40
# 2                               45
# 3                               50
# 4                               50

# %%
total_rows = len(data['Name'])
print(total_rows)
# Out:
# 27106

# %%
'''
Visualized the historical hurricane on map based on its first original location
'''

# Sort dataframe by year, month, and day to get the earliest point for each hurricane
df_sorted = data.sort_values(by=['date_time'])

# Drop duplicate hurricanes, keeping only the earliest point for each one
df_earliest = df_sorted.drop_duplicates(subset='Name', keep='first')

# Create a map centered around the data's average location
m = folium.Map(location=[df_earliest['Latitude'].mean(), df_earliest['Longitude'].mean()], zoom_start=4)

# Add data points to the map
for idx, row in df_earliest.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Name']} ({row['Year']})",
        icon=folium.Icon(icon='cloud', color='blue')
    ).add_to(m)
m
# Save map to an HTML file
#m.save('hurricanes_map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86f47d5538a61a8321b62a552909d87e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86f47d5538a61a8321b62a552909d87e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_86f47d5538a61a8321b62a552909d87e = L.map(
#                 &quot;map_86f47d5538a61a8321b62a552909d87e&quot;,
#                 {
#                     center: [21.86549520766772, -62.15814696485628],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c69433d0bbdba47bfb2932b6efc9f0ad = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86f47d5538a61a8321b62a552909d87e);
#
#
#             var marker_9d8e5d44038924544be67a6cc87259fe = L.marker(
#                 [29.6, -63.7],
#                 {}
#             ).addTo(map_86f47d5538a61a8321b62a552909d87e);
#
#
#             var icon_7504b69f87513e59c56f73ccd8f23633 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d8e5d44038924544be67a6cc87259fe.setIcon(icon_7504b69f87513e59c56f73ccd8f23633);
#
#
#         var popup_50cd16d8b84b5d9a9d8665c1eefe07f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9462d35569ff0b52786f85a59027f0e = $(`&lt;div id=&quot;html_e9462d35569ff0b52786f85a59027f0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GEORGE (1950)&lt;/div&gt;`)[0];
#                 popup_50cd16d8b84b5d9a9d8665c1eefe07f3.setContent(html_e9462d35569ff0b52786f85a59027f0e);
#
#
#
#         marker_9d8e5d44038924544be67a6cc87259fe.bindPopup(popup_50cd16d8b84b5d9a9d8665c1eefe07f3)
#         ;
#
#
#
#
#             var marker_341c254819b0615b2231fdab38831247 = L.marker(
#                 [25.6, -88.4],
#                 {}
#             ).addTo(map_86f47d5538a61a8321b62a552909d87e);
#
#
#             var icon_15a23bcd058e1df4c02e4d63bc7facc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_341c254819b0615b2231fdab38831247.setIcon(icon_15a23bcd058e1df4c02e4d63bc7facc3);
#
#
#         var popup_740da9f3f137ace562f217fe6c284fbc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0cc4c421398a2b3959f589f4a7005dbc = $(`&lt;div id=&quot;html_0cc4c421398a2b3959f589f4a7005dbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HOW (1950)&lt;/div&gt;`)[0];
#                 popup_740da9f3f137ace562f217fe6c284fbc.setContent(html_0cc4c421398a2b3959f589f4a7005dbc);
#
#
#
#         marker_341c254819b0615b2231fdab38831247.bindPopup(popup_740da9f3f137ace562f217fe6c284fbc)
#         ;
#
#
#
#
#             var marker_92ba7272fc6b77b6b1827d895d7d035f = L.marker(
#                 [20.5, -94.3],
#                 {}
#             ).addTo(map_86f47d5538a61a8321b62a552909d87e);
#
#
#             var icon_3f63912ee71a7a22456cb39f9fbf22e9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_92ba7272fc6b77b6b1827d895d7d035f.setIcon(icon_3f63912ee71a7a22456cb39f9fbf22e9);
#
#
#         var popup_cfe0da42ed03660b49e3ed05dbfe9c5b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25e0abc2c19d219438bc98a1b4a2faf3 = $(`&lt;div id=&quot;html_25e0abc2c19d219438bc98a1b4a2faf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ITEM (1950)&lt;/div&gt;`)[0];
#                 popup_cfe0da42ed03660b49e3ed05dbfe9c5b.setContent(html_25e0abc2c19d219438bc98a1b4a2faf3);
#
#
#
#         marker_92ba7272fc6b77b6b1827d895d7d035f.bindPopup(popup_cfe0da42ed03660b49e3ed05dbfe9c5b)
#         ;
#
#
#
#
#             var marker_c928e79d8525e7333f2938ccd394e1c0 = L.marker(
#                 [22.4, -47.0],
#                 {}
#             ).addTo(map_86f47d5538a61a8321b62a552909d87e);
#
#
#             var icon_893a11e2a1a902e43fb01cc4271ace86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c9

# %%
'''
Visualized the historical hurricane between 2017 to 2022 on the map and used different color to distribute the point
'''

# Filter data for years 2017 - 2022
df_filtered = data[(data['Year'] >= 2017) & (data['Year'] <= 2022)]

# Sort dataframe by year, month, and day to get the earliest point for each hurricane in the filtered range
df_sorted = df_filtered.sort_values(by=['date_time'])

# Drop duplicate hurricanes, keeping only the earliest point for each one
df_earliest = df_sorted.drop_duplicates(subset='Name', keep='first')

# Create a color map based on years
year_to_color = {year: color for year, color in zip(range(2017, 2023), 
                                                    ['red', 'blue', 'green', 'purple', 'orange', 'lightblue'])}

# Create a map centered around the data's average location
m = folium.Map(location=[df_earliest['Latitude'].mean(), df_earliest['Longitude'].mean()], zoom_start=4)

# Add data points to the map
for idx, row in df_earliest.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Name']} ({row['Year']})",
        icon=folium.Icon(icon='cloud', color=year_to_color[row['Year']])
    ).add_to(m)

legend_html = '''
<div style="position: fixed; 
            bottom: 50px; left: 50px; width: 150px; height: 130px; 
            border:2px solid grey; z-index:9999; font-size:14px;
            background:white;
            ">
    &nbsp;<b>Year Legend</b><br>
'''
for year, color in year_to_color.items():
    legend_html += f'<i class="fa fa-circle" style="color:{color}"></i>&nbsp;{year}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

# Save map to an HTML file
#m.save('hurricanes_map_2017_2022.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42e067c24d5b7dbf5616d50f3700f867 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
# &lt;div style=&quot;position: fixed;
#             bottom: 50px; left: 50px; width: 150px; height: 130px;
#             border:2px solid grey; z-index:9999; font-size:14px;
#             background:white;
#             &quot;&gt;
#     &amp;nbsp;&lt;b&gt;Year Legend&lt;/b&gt;&lt;br&gt;
# &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&amp;nbsp;2017&lt;br&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt;&amp;nbsp;2018&lt;br&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green&quot;&gt;&lt;/i&gt;&amp;nbsp;2019&lt;br&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:purple&quot;&gt;&lt;/i&gt;&amp;nbsp;2020&lt;br&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:orange&quot;&gt;&lt;/i&gt;&amp;nbsp;2021&lt;br&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:lightblue&quot;&gt;&lt;/i&gt;&amp;nbsp;2022&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42e067c24d5b7dbf5616d50f3700f867&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_42e067c24d5b7dbf5616d50f3700f867 = L.map(
#                 &quot;map_42e067c24d5b7dbf5616d50f3700f867&quot;,
#                 {
#                     center: [23.331404958677687, -60.166115702479345],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_618ce452f9a205fbf2356655ae06480e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42e067c24d5b7dbf5616d50f3700f867);
#
#
#             var marker_ff35992e7f5cae56cba4acd1c5bab991 = L.marker(
#                 [42.2, -42.6],
#                 {}
#             ).addTo(map_42e067c24d5b7dbf5616d50f3700f867);
#
#
#             var icon_af0a7ba093fcc2205f583f00c50f59cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ff35992e7f5cae56cba4acd1c5bab991.setIcon(icon_af0a7ba093fcc2205f583f00c50f59cc);
#
#
#         var popup_065260be9715e4c2c8e98e32459ad0d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a82e3193d188a99a9d1a218faa7effe = $(`&lt;div id=&quot;html_9a82e3193d188a99a9d1a218faa7effe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MARIA (2017)&lt;/div&gt;`)[0];
#                 popup_065260be9715e4c2c8e98e32459ad0d1.setContent(html_9a82e3193d188a99a9d1a218faa7effe);
#
#
#
#         marker_ff35992e7f5cae56cba4acd1c5bab991.bindPopup(popup_065260be9715e4c2c8e98e32459ad0d1)
#         ;
#
#
#
#
#             var marker_fded16492547fdd9525b9b738c456ce4 = L.marker(
#                 [44.2, -72.0],
#                 {}
#             ).addTo(map_42e067c24d5b7dbf5616d50f3700f867);
#
#
#             var icon_f5eaf3aa6962cbff6a39e7c8ea01c489 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fded16492547fdd9525b9b738c456ce4.setIcon(icon_f5eaf3aa6962cbff6a39e7c8ea01c489);
#
#
#         var popup_8baaa677e8c0fd9990a13cf391be22dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cce4a795c92af45c92a6587c63d582f = $(`&lt;div id=&quot;html_1cce4a795c92af45c92a6587c63d582f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NATE (2017)&lt;/div&gt;`)[0];
#                 popup_8baaa677e8c0fd9990a13cf391be22dc.setContent(html_1cce4a795c92af45c92a6587c63d582f);
#
#
#
#         marker_fded16492547fdd9525b9b738c456ce4.bindPopup(popup_8baaa677e8c0fd9990a13cf391be22dc)
#         ;
#
#
#
#
#             var marker_2e06f5f6ace011b0cb5798f84821d0e0 = L.marker(
#                 [32.0, -39.1],
#                 {}
#             ).addTo(map_42e067c24d5b7dbf5616d50f3700f867);
#
#
#             var icon_ad9d2dfc7e6a4dbd4bd762878bb25d7d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2e06f5f6ace011b0cb5798f84821d0e0.setIcon(icon_ad9d2dfc7e6a4dbd4bd762878bb25d7d);
#
#
#         var popup_9d5c52ec4ea82bdfbfba4be3da688314 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd24ea552f42d3be67f31c6dde8e181d = $(`&lt;div id=&quot

# %%
'''
Map of Category 5 Hurricane
Created a map that only include historical hurricane from 2017 to 2022
'''

# Filter data for years 2017 - 2022 and where Maximum_sustained_wind_in_knots is greater than 137 (Category 5)
df_filtered = data[(data['Year'] >= 2017) & (data['Year'] <= 2022) & (data['Maximum_sustained_wind_in_knots'] >= 137)]

# Sort dataframe by year, month, and day
df_sorted = df_filtered.sort_values(by=['date_time'])
df_cat5 = df_sorted.drop_duplicates(subset='Name', keep='first')

# Create a color map based on years
year_to_color = {year: color for year, color in zip(range(2017, 2023),
                                                    ['red', 'blue', 'green', 'purple', 'orange', 'purple'])}
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]


# Create a map centered around the average location of the Category 5 hurricanes
m = folium.Map(location=[df_cat5['Latitude'].mean(), df_cat5['Longitude'].mean()], zoom_start=4)


for idx, row in df_cat5.iterrows():
    color = year_to_color.get(row['Year'], "gray")  # Default to "gray" if the year doesn't match any key
    month_name = months[int(row['Month']) - 1]  # Convert month number to month name
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Name']} ({row['Year']})",
        icon=folium.DivIcon(html=f"""<div style="color: {color};">{row['Name']} {int(row['Year'])} {month_name}</div>""")
    ).add_to(m)

# Save map to an HTML file
#m.save('category5_hurricanes_map_2017_2022.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e599ecd9c84fdc872dbc3dbada7d08a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e599ecd9c84fdc872dbc3dbada7d08a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0e599ecd9c84fdc872dbc3dbada7d08a = L.map(
#                 &quot;map_0e599ecd9c84fdc872dbc3dbada7d08a&quot;,
#                 {
#                     center: [23.116666666666664, -67.95],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71b17270a585ffce9d7d0c7f11d1e931 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e599ecd9c84fdc872dbc3dbada7d08a);
#
#
#             var marker_513ccbdfe55615cad45967e145f468aa = L.marker(
#                 [15.3, -61.1],
#                 {}
#             ).addTo(map_0e599ecd9c84fdc872dbc3dbada7d08a);
#
#
#             var div_icon_454fd6cd14d345541c473cc94db7e79a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: red;\&quot;\u003eMARIA 2017 Sep\u003c/div\u003e&quot;});
#             marker_513ccbdfe55615cad45967e145f468aa.setIcon(div_icon_454fd6cd14d345541c473cc94db7e79a);
#
#
#         var popup_2153633f9c14cfe8acdec9f8aa8c168f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d62d1836768f2ea5930e795613b00f3a = $(`&lt;div id=&quot;html_d62d1836768f2ea5930e795613b00f3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MARIA (2017)&lt;/div&gt;`)[0];
#                 popup_2153633f9c14cfe8acdec9f8aa8c168f.setContent(html_d62d1836768f2ea5930e795613b00f3a);
#
#
#
#         marker_513ccbdfe55615cad45967e145f468aa.bindPopup(popup_2153633f9c14cfe8acdec9f8aa8c168f)
#         ;
#
#
#
#
#             var marker_586be192730dba10a0aefda8fe5e5ad2 = L.marker(
#                 [16.7, -57.8],
#                 {}
#             ).addTo(map_0e599ecd9c84fdc872dbc3dbada7d08a);
#
#
#             var div_icon_9144966dc84f28d73f83be437d3285c7 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: red;\&quot;\u003eIRMA 2017 Sep\u003c/div\u003e&quot;});
#             marker_586be192730dba10a0aefda8fe5e5ad2.setIcon(div_icon_9144966dc84f28d73f83be437d3285c7);
#
#
#         var popup_ea895b248c9cd6cecf939f49d828ca33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc334ddc157b58a53af852c139d7a487 = $(`&lt;div id=&quot;html_bc334ddc157b58a53af852c139d7a487&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IRMA (2017)&lt;/div&gt;`)[0];
#                 popup_ea895b248c9cd6cecf939f49d828ca33.setContent(html_bc334ddc157b58a53af852c139d7a487);
#
#
#
#         marker_586be192730dba10a0aefda8fe5e5ad2.bindPopup(popup_ea895b248c9cd6cecf939f49d828ca33)
#         ;
#
#
#
#
#             var marker_13013bf49cccbadd7f3c37312e505bff = L.marker(
#                 [30.0, -85.5],
#                 {}
#             ).addTo(map_0e599ecd9c84fdc872dbc3dbada7d08a);
#
#
#             var div_icon_7fdbae0516310abe1d7b741a7238d1f3 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: blue;\&quot;\u003eMICHAEL 2018 Oct\u003c/div\u003e&quot;});
#             marker_13013bf49cccbadd7f3c37312e505bff.setIcon(div_icon_7fdbae0516310abe1d7b741a7238d1f3);
#
#
#         var popup_b8688c61e1d31fe30d2f2569aa735cf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d536beb4b58c2bc9cb3c57017ee1fc1 = $(`&lt;div id=&quot;html_2d536beb4b58c2bc9cb3c57017ee1fc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MICHAEL (2018)&lt;/div&gt;`)[0];
#                 popup_b8688c61e1d31fe30d2f2569aa735cf9.setContent(html_2d536beb4b58c2bc9cb3c57017ee1fc1);
#
#
#
#         marker_13013bf49cccbadd7f3c37312e505bff.bindPopup(popup_b8688c61e1d31fe30d2f2569aa735cf9)
#         ;
#
#
#
#
#             var marker_0a5a71f81e6a929ff0e6f98115ee377b = L.marker(
#                 [26.4, -75.6],
#                 {}
#             ).addTo(map_0e599ecd9c84fdc872dbc3dbada7d08a);
#
#
#             var div_icon_c0194d167670295445a0ba93e832f21d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: green;\&quot;\u003eDORIAN 2019 Sep\u003c/div\u003e&quot;});
#             marker_0a5a71f81e6a929ff0e6f98115ee377b.setIcon(div_icon_c0194d167670295445a0ba93e832f21d);
#
#
#         var popup_044d139992f5c0775fb0ff72faa8fa3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81df3708a1f986ff94cf41334528f1a6 = $(`&lt;div id=&quot;html_81df3708a1f986ff94cf41334528f1a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DOR

# %%
# Detailed information of category 5 hurricane from 2017 to 2022
df_cat5
# Out:
#           Name         date_time  Year  Month  Day  Hours_in_UTC  Latitude  \
# 23884    MARIA   2017/9/19 00:00  2017      9   19             0      15.3
# 23668     IRMA    2017/9/5 12:00  2017      9    5            12      16.7
# 24581  MICHAEL  2018/10/10 17:30  2018     10   10            17      30.0
# 24754   DORIAN    2019/9/1 06:00  2019      9    1             6      26.4
# 24986  LORENZO   2019/9/29 03:00  2019      9   29             3      24.3
# 26947      IAN   2022/9/28 12:00  2022      9   28            12      26.0
#
#        Longitude  Maximum_sustained_wind_in_knots
# 23884      -61.1                              145
# 23668      -57.8                              150
# 24581      -85.5                              140
# 24754      -75.6                              145
# 24986      -45.0                              140
# 26947      -82.7                              140

# %%
'''
Research for average original location of hurrican happened in September and October between 1990 to 2022
'''

# Filter data for hurricanes between September and October
df_filtered = data[(data['Year'] > 1990)&(data['Month'] >= 9) & (data['Month'] <= 10) ]

df_sorted = df_filtered.sort_values(by=['date_time'])

# Drop duplicate hurricanes, keeping only the first point for each Category 5 hurricane in this time frame
df_filtered_1 = df_sorted.drop_duplicates(subset='Name', keep='first')

# Group by year and compute average latitude and longitude
grouped = df_filtered_1.groupby('Year').agg(average_latitude=('Latitude', 'mean'), average_longitude=('Longitude', 'mean')).reset_index()

'''
The data of EL Nino: https://ggweather.com/enso/oni.htm
'''
# List of EL Nino & La Nino
strong_el =[1957, 1958, 1965, 1966, 1972, 1973, 1987, 1988, 1982, 1983, 1991, 1992, 1997, 1998, 2015, 2016]
strong_la = [1973, 1973, 1975, 1976, 1988, 1989, 1998, 1999, 1999, 2000, 2007, 2008, 2010, 2011]

# Define color mapping
def get_color(year):
    if year in strong_el:
        return 'red'
    elif year in strong_la:
        return 'green'
    else:
        return 'blue'

def compute_avg_location_for_color(color):
    filtered_years = []
    
    if color == "red":
        filtered_years = strong_el
    elif color == "green":
        filtered_years = strong_la
    else:  # for blue or normal
        filtered_years = [year for year in grouped['Year'] if year not in strong_el and year not in strong_la]
    
    category_data = grouped[grouped['Year'].isin(filtered_years)]
    return category_data['average_latitude'].mean(), category_data['average_longitude'].mean()

# Compute average locations for red, green, and blue categories
avg_lat_red, avg_lon_red = compute_avg_location_for_color("red")
avg_lat_green, avg_lon_green = compute_avg_location_for_color("green")
avg_lat_blue, avg_lon_blue = compute_avg_location_for_color("blue")

print("Strong EL Avg location:", avg_lat_red, avg_lon_red)
print("Strong La Avg location:", avg_lat_green, avg_lon_green)
print("Normal Avg location:", avg_lat_blue, avg_lon_blue)

# Create a map centered around the average locations
m = folium.Map(location=[grouped['average_latitude'].mean(), grouped['average_longitude'].mean()], zoom_start=4)

# Add data points to the map
for idx, row in grouped.iterrows():
    color = get_color(row['Year'])
    folium.map.Marker(
        [row['average_latitude'], row['average_longitude']],
        icon=folium.DivIcon(html=f"""<div style="color: {color};">{int(row['Year'])}</div>""")
    ).add_to(m)

folium.Marker([avg_lat_red, avg_lon_red], icon=folium.Icon(color='red', icon='info-sign'), popup="Avg Strong El Niño").add_to(m)
folium.Marker([avg_lat_green, avg_lon_green], icon=folium.Icon(color='green', icon='info-sign'), popup="Avg Strong La Niña").add_to(m)
folium.Marker([avg_lat_blue, avg_lon_blue], icon=folium.Icon(color='blue', icon='info-sign'), popup="Avg Normal").add_to(m)

legend_html = '''
<div style="position: fixed; 
            bottom: 50px; left: 50px; width: 150px; height: 90px; 
            border:2px solid grey; z-index:9999; font-size:14px;
            background-color:white;
            ">
    <b>Legend:</b><br>
    <i class="fa fa-square" style="color: red"></i> Strong El Niño<br>
    <i class="fa fa-square" style="color: green"></i> Strong La Niña<br>
    <i class="fa fa-square" style="color: blue"></i> Normal
</div>
'''

m.get_root().html.add_child(folium.Element(legend_html))
# Save map to an HTML file
#m.save('hurricanes_avg_location_map.html')
m
# Out:
# Strong EL Avg location: 24.200380952380954 -53.14857142857143
# Strong La Avg location: 21.327692743764175 -60.54362244897959
# Normal Avg location: 22.475901875901872 -56.736327561327556
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_159e60ff6780780add69b606112ee92d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
# &lt;div style=&quot;position: fixed;
#             bottom: 50px; left: 50px; width: 150px; height: 90px;
#             border:2px solid grey; z-index:9999; font-size:14px;
#             background-color:white;
#             &quot;&gt;
#     &lt;b&gt;Legend:&lt;/b&gt;&lt;br&gt;
#     &lt;i class=&quot;fa fa-square&quot; style=&quot;color: red&quot;&gt;&lt;/i&gt; Strong El Niño&lt;br&gt;
#     &lt;i class=&quot;fa fa-square&quot; style=&quot;color: green&quot;&gt;&lt;/i&gt; Strong La Niña&lt;br&gt;
#     &lt;i class=&quot;fa fa-square&quot; style=&quot;color: blue&quot;&gt;&lt;/i&gt; Normal
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_159e60ff6780780add69b606112ee92d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_159e60ff6780780add69b606112ee92d = L.map(
#                 &quot;map_159e60ff6780780add69b606112ee92d&quot;,
#                 {
#                     center: [22.25632470020401, -57.015836318853566],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_946784ea3f3cfcd16024c4bd113b643e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_159e60ff6780780add69b606112ee92d);
#
#
#             var marker_fcbbac243d15938acf24b5a336febcc9 = L.marker(
#                 [25.14, -60.980000000000004],
#                 {}
#             ).addTo(map_159e60ff6780780add69b606112ee92d);
#
#
#             var div_icon_ac550e571ab05cbde44c1144c6ef3646 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: red;\&quot;\u003e1991\u003c/div\u003e&quot;});
#             marker_fcbbac243d15938acf24b5a336febcc9.setIcon(div_icon_ac550e571ab05cbde44c1144c6ef3646);
#
#
#             var marker_9b33a8d912214384addcd6e61db6888c = L.marker(
#                 [31.5, -53.120000000000005],
#                 {}
#             ).addTo(map_159e60ff6780780add69b606112ee92d);
#
#
#             var div_icon_6c378d2b035ffef634be8d80cc98e671 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: red;\&quot;\u003e1992\u003c/div\u003e&quot;});
#             marker_9b33a8d912214384addcd6e61db6888c.setIcon(div_icon_6c378d2b035ffef634be8d80cc98e671);
#
#
#             var marker_5205ff974fb1bf0ff83d02c85e4487e6 = L.marker(
#                 [29.174999999999997, -67.825],
#                 {}
#             ).addTo(map_159e60ff6780780add69b606112ee92d);
#
#
#             var div_icon_bb2add6c705581e0fc14371ff305e930 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: blue;\&quot;\u003e1993\u003c/div\u003e&quot;});
#             marker_5205ff974fb1bf0ff83d02c85e4487e6.setIcon(div_icon_bb2add6c705581e0fc14371ff305e930);
#
#
#             var marker_6e322cab1413541e4b563cca99d73819 = L.marker(
#                 [11.899999999999999, -45.05],
#                 {}
#             ).addTo(map_159e60ff6780780add69b606112ee92d);
#
#
#             var div_icon_a56994bddf3c8e1faf4926b96473ae6f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: blue;\&quot;\u003e1994\u003c/div\u003e&quot;});
#             marker_6e322cab1413541e4b563cca99d73819.setIcon(div_icon_a56994bddf3c8e1faf4926b96473ae6f);
#
#
#             var marker_cfc11c16a4ec35ddc788c06ce31badd1 = L.marker(
#                 [22.163636363636364, -54.40909090909091],
#                 {}
#             ).addTo(map_159e60ff6780780add69b606112ee92d);
#
#
#             var div_icon_92766a97475a708356fabfa5620dd477 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: blue;\&quot;\u003e1995\u003c/div\u003e&quot;});
#             marker_cfc11c16a4ec35ddc788c06ce31badd1.setIcon(div_icon_92766a97475a708356fabfa5620dd477);
#
#
#             var marker_dd3befa3f58b67d035633d6a44da7a9a = L.marker(
#                 [24.825, -63.974999999999994],
#                 {}
#             ).addTo(map_159e60ff6780780add69b606112ee92d);
#
#
#             var div_icon_66c66246d19a57b5b4934275918b87e2 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;color: blue;\&quot;\u003e1996\u003c/div\u003e&quot;});
#             marker_dd3befa3f58b67d035633d6a44da7a9a.setIcon(div_icon_66c66246d19a57b5b4934275918b87e2);
#
#
#             var marker_b8441d25bca801c2261396b498cdcd15 = L.marker(
#                 [29.428571428571427, -57.34285714285714],
#                 {}
#             ).addTo(map_159e60ff6780780add69b606112ee92d);
#
#
#             var div_icon_dcde3bda5e376fdb73cc14226b8eb013 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003
